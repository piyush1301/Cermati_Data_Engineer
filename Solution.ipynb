# %% [markdown]
# <body bgcolor="#E6E6FA">
#   <div>  <img src="https://netbramha.com/wp-content/uploads/2016/12/senior-front-end-developer-openings-1.gif" align=left width=300px height=300px><h1>&nbsp;&nbsp;&nbsp;&nbsp; Python <br> &nbsp;&nbsp;&nbsp;&nbsp; Cermati.com - Bengaluru, India <br> &nbsp;&nbsp;&nbsp;&nbsp; Data Engineer - India </h1><img src='' align=right width=200px height=100px>
# </div>

# %% [markdown]
# # Importing Python Library

# %%
import urllib
import re
import spacy
from spacy import displacy
import en_core_web_sm
from bs4 import BeautifulSoup as bs
import xml.etree.ElementTree as ET
import json
import datetime
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # User Defined function

# %%
def remove_tags(text):
    # getting orignal Text from HTML/XML
    return ''.join(ET.fromstring(text).itertext())

def get_detailsfromlink(i):
    # variable assignment 
    title='';Qulification='';by='';role='';place=''
    soup = bs(urllib.request.urlopen(i).read().decode("utf-8"))
    
    # extracting data
    title=soup.find_all("h1", class_="job-title")
    role=soup.find_all("div", class_="wysiwyg",itemprop='responsibilities')
    Qulification=soup.find_all("div", class_="wysiwyg",itemprop='qualifications')
    by=soup.find_all("h3", class_="details-title")
    place=soup.find_all("span",class_="job-detail")
    
    #condition ---- if data is missing 
    if len(title)!=0 :
        title=remove_tags(title[0].encode('utf-8'))
    if len(Qulification)!=0:
        Qulification=remove_tags(Qulification[0].encode('utf-8'))
    if len(role)!=0:
        role=remove_tags(role[0].encode('utf-8'))
    if len(place)!=0:
        place=remove_tags(place[0].encode('utf-8'))
    if len(by)!=0:
        by=remove_tags(by[0].encode('utf-8'))
    # return the data
    return title,Qulification,role,place,by

# %% [markdown]
# # Connecting to server
# # Decoding the Text
# # Apply Bs4

# %%
response = urllib.request.urlopen('https://www.cermati.com/karir/')
print(response.info())
html = response.read()
html=html.decode("utf-8")
html=html.replace('\n','')
soup = bs(html)
# Out:
# Server: nginx
# Date: Thu, 28 Nov 2019 12:26:06 GMT
# Content-Type: text/html; charset=utf-8
# Content-Length: 135861
# Connection: close
# Vary: Accept-Encoding
# x-frame-options: sameorigin
# X-Request-Id: d5bbfec1-ab75-4f40-a9cd-8d21c02fe8f8
# set-cookie: _csrf=s%3ASkHLyZCmcdTkTIZUtpeAMn2A.b7AZW5dgygUJwy2xfawgBIaxb90Ezipme%2BftsasNFCI; Path=/; HttpOnly
# set-cookie: keystone.sid=s%3AZnQSd4UJ0pimJBzLY4hpsM9ZX4M4uCHm.IDg%2BGBvitqkLlVbEKl1Tu9e0QnnnIwmgZinU8trvMOE; Path=/; HttpOnly
# Cache-Control: no-transform
# ETag: W/"212b5-cQBXOMvOJq5JmhltSDvefLkksTM"
# X-XSS-Protection: 1; mode=block
# X-Content-Type-Options: nosniff
# Strict-Transport-Security: max-age=31536000; includeSubDomains

# %% [markdown]
# # Using Regex to get some initial data (BS4 can also be used but regex will be faster with string opration)

# %%
import re
pat_main ='(?<=\<div class="tab-content">).+?(?=\<div class="row">)'
op_list=re.findall(pat_main,html)
pat_Dep = '(?<=\<h4 class="tab-title">).+?(?=\</h4>)'
op_list_=re.findall(pat_Dep, op_list[0])

# %% [markdown]
# # Extracting All the Department

# %%
each_dip=[]
for i in range(len(op_list_)):
    i="tab"+str(i)
    each_dip.append(soup.find_all("div", {"id": i})[0])

# %% [markdown]
# # Extracting All the Department Data

# %%
each_dip_data=[]
for i in range(len(each_dip)):
    soup = bs(str(each_dip[i]))
    each_dip_data.append(soup.find_all("div", class_="dept-label col-sm-7"))

# %% [markdown]
# # Total Department List/Number

# %%
len(each_dip_data)
# Out:
# 6

# %% [markdown]
# # Extracting All the the link with each Department in list of list

# %%
each_dip_data_link=[[] for i in range(len(op_list_))]
for i in range(len(op_list_)):
    soup = bs(str(each_dip[i]))
    for link in soup.findAll("a"):
        each_dip_data_link[i].append(link.get("href"))

# %% [markdown]
# # Running Custom function in each link to get Details as per requirement.

# %%
full_data={}
for i in op_list_:
    full_data[i]=[]
    print('------------------->')
    print(datetime.datetime.now())
    for j in range(len(each_dip_data_link)):
        for k in each_dip_data_link[j]:
            k=str(k).replace(' ','%20')
            try:
                title,Qulification,role,place,by=get_detailsfromlink(k)
                temp={"title":title,"location":place,"description":role,"qualification":Qulification,"posted by":by}
                full_data[i].append(temp)
            except:
                print(k)
                print('Error occur with above link')
                print('<-----------')
# Out:
# ------------------->
# 2019-11-28 17:56:07.032350
# ------------------->
# 2019-11-28 17:56:55.818013
# ------------------->
# 2019-11-28 17:57:46.693805
# ------------------->
# 2019-11-28 17:58:36.303084
# ------------------->
# 2019-11-28 17:59:25.332106
# ------------------->
# 2019-11-28 18:00:20.446712

# %% [markdown]
# # Full Data with All the details

# %%
full_data
# Out:
# {'Engineering': [{'title': 'Software Engineer (Senior/Principal/Architect) - Singapore',
#    'location': 'Singapore',
#    'description': "Contribute to all aspects of the software development lifecycle including design, development, documentation, testing and operationsCreate code that's easy to readWork with your team to maintain, improve and clean your codeReview each other's code and learn the software engineering best practices hereDeliver good quality code in a reasonable timeline",
#    'qualification': "Bachelor’s Degree (S1) in Computer Science or related field. Or if you don't have a Bachelor's degree, prove to us that you can code at the same level as other software engineerProficiency in, at least, one programming language such as Java or Javascript,\xa0High level understanding on how the internet works (HTTP, DNS, IP, Server-client interaction, etc)Preferred Qualifications (Not required but nice to have):Experience building scalable web servicesExperience in coding competitionsExperience with AWS or other PAAS.Experience with LinuxExperience with basic tooling like git, browser debugging, bash scripting, etc.Experience with Search & Personalization or Machine Learning",
#    'posted by': 'Aldo Winata'},
#   {'title': 'Data Scientist  (Junior/Senior/Principal/Architect) - Singapore',
#    'location': 'Singapore',
#    'description': "Analyze data to bring insights that can help solve problem or prevent future problem to arise.Create hypothesis and test hypothesis using our data. If we don't have the data, propose a way to capture and extract the needed data to stakeholders.\xa0Train data model based on our current data\xa0Define and monitor key metrics and alert the business on potential issues.Analyze operational efficiency and build business models to guide decision-making.\xa0Design market/business intelligence reports and performance measurement dashboards.\xa0Enhance our data infra, analyze large, complex data sets into actionable insights.",
#    'qualification': 'At least a Bachelor degree in computing intensive subjects, e.g. finance, financial mathematics, computer science, mathematics, physics, bio-informatics, engineering\xa0Knowledgeable in SQL, data visualization using tools like Tableau and can code basic Python/R\xa0Advanced statistics knowledge\xa0Unafraid to deal with large, dirty, and messy data and can create ETL to clean and make the data workable - Amazing problem solver\xa0Experienced in using advanced analytics/machine learning in the real world scenarioPast participation in science Olympiad or Kaggle is a plusProficiency in Java or Phyton.',
#    'posted by': 'Aldo Winata'},
#   {'title': 'Android Developer (Senior/Principal/Architect) - Singapore',
#    'location': 'Singapore',
#    'description': "Develop the Android applicationContribute to all aspects of the Android development lifecycle including design, development, documentation, testing and operationsCreate clean, easy to read code within reasonable timelineReview each other's code and learn the software engineering best practices",
#    'qualification': "Bachelor's Degree (S1) in Computer Science or related field. Or if you don't have a Bachelor's degree, prove to us that you can code at the same level as other software engineerProficiency in, at least, one programming language such as Java & Kotlin.Experience in Android Native.Experience in Android development is a must. Having developed an Android app from scratch to publication is a big plus",
#    'posted by': 'Aldo Winata'},
#   {'title': 'IOS Developer (Senior/Principal/Architect) - Singapore',
#    'location': 'Singapore',
#    'description': "Develop the iOS application for Cermati\xa0Contribute to all aspects of the IOS development lifecycle including design, development, documentation, testing and operations\xa0Create clean, easy to read code within reasonable timeline\xa0Review each other's code and learn the software engineering best practices\xa0",
#    'qualification': "Bachelor's Degree (S1) in Computer Science or related field. Or if you don't have a Bachelor's degree, prove to us that you can code at the same level as other software engineer\xa0Proficiency in,programming language such as Swift.Experience in native iPhone and iPad development is a must.\xa0Having developed an IOS app from scratch to publication is a big plus",
#    'posted by': 'Aldo Winata'},
#   {'title': 'Software Engineer (Lead/Manager/Head) - Singapore',
#    'location': 'Singapore',
#    'description': "Lead and mentor junior engineers to develop their skills and grow their careers at CermatiUnderstand Cermati's business and improve cermati's business with the help of your engineering teamHire and help the company find new engineering talentResponsible for managing, growing your team as well as your team member's promotions, demotions, hiring, firing, etc.Ensure that your team is happy, motivated and productive at CermatiWork with your team to build features, to maintain old code, improve and clean the code that your team ownsContribute to design decision and review each other's codeMake sure the code that your team owns will be available 24/7 and you're willing to troubleshoot and maintain the services that your team ownsWork together with product manager to set the feature specs and set the target deadline.Drive the projects so you can meet the deadline with your team",
#    'qualification': "Bachelor’s Degree (S1) in Computer Science or related field. Or if you don't have a Bachelor's degree, prove to us that you can code at the same level as other software engineerProficiency in, at least, one programming language such as\xa0Java or JavascriptHas high level understanding on how the internet works (HTTP, DNS, IP, Server-client interaction, etc)Experience building scalable web servicesProven record of good mentorship and leadership in delivering high quality projectsAt least 3 years experience working in a good tech oriented companyAt least have 2 years experience manage people and team.Preferred Qualifications (Not required but nice to have):Experience in coding competitionsExperience with AWS or other PAAS.Experience with LinuxExperience with basic tooling like git, browser debugging, bash scripting, etc.Experience with Search & Personalization or Machine Learning",
#    'posted by': 'Aldo Winata'},
#   {'title': 'IOS Developer - India',
#    'location': 'Bengaluru, Karnataka, India',
#    'description': "\xa0Develop the iOS application for Cermati\xa0Contribute to all aspects of the Android development lifecycle including design, development, documentation, testing and operations\xa0Create clean, easy to read code within reasonable timeline\xa0Review each other's code and learn the software engineering best practices\xa0This is a full time job and not an internship\xa0",
#    'qualification': "\xa0Bachelor's Degree (S1) in Computer Science or related field. Or if you don't have a Bachelor's degree, prove to us that you can code at the same level as other software engineer\xa0Proficiency in, at least, one programming language such as Objective C, Swift, Java, Python, Javascript\xa0Experience in native iPhone and iPad development is a must.\xa0Having developed an IOS app from scratch to publication is a big plus\xa0",
#    'posted by': []},
#   {'title': 'Frontend Developer - India',
#    'location': 'Bengaluru, Karnataka, India',
#    'description': "Contribute to all aspects of the software development lifecycle including design, development, documentation, testing and operationsCreate code that's easy to readWork with your team to maintain, improve and clean your codeReview each other's code and learn software engineering best practice hereDeliver good quality code in a reasonable timeline\xa0",
#    'qualification': "Basic Qualifications:Bachelor (S1) Degree in Computer Science or if you don't have a Bachelor's degree, prove to us that you can code at the same level as other software engineer (we have people in our team who doesn't have Bachelor in computer science)Experience and passion in web technologies styling, web performance and javascript (HTML5/CSS3/Javascript)Passion and curiosity to explore new things and keep abreast with new front end technologiesHas high level understanding on how the internet works (HTTP, DNS, IP, Server-client interaction, etc)Preferred Qualifications (Not required but nice to have):Proficiency in, at least, one programming language such as Java, PHP, Javascript, Python, Ruby, Rust, Go, Haskell.Comfortable working in server code although not very deepHas prior experience as a software developer or UX designerExperience with LinuxExperience with basic tooling like git, browser debugging, bash scripting, etc.Experience in coding competitionsUnderstand how to create a code with browser compatibility in different platform (android, desktop, iOS)",
#    'posted by': []},
#   {'title': 'Data Engineer - India',
#    'location': 'Bengaluru, Karnataka, India',
#    'description': "\xa0Work with different business and technical teams across the company to establish unified definitions, systems, and data governance for key metrics.Build scalable backend solutions for automation of data processing;Develop predictive/segmentation models to understand our customers' behavior and convert that to actionables that will drive product/marketing/sales key metrics;Initiate and drive projects to completion with minimal guidance\xa0",
#    'qualification': 'The following technical skills would be useful:Candidates must be able to understand the tradeoff between performance, simplicity, maintainability and timeline constraints when developing software solutionsStrong hands on experience in java, python is required. Must have shipped multiple projects with a major hands on contribution to each project.Experience in Big data technologies: hadoop ecosystem (mapreduce, spark, kafka)Experience in different storage technologies: OLTP like postgres, OLAP like redshift, Google bigquery, NoSQl like redis, hbase, kafkaFamiliarity with machine learning algorithms and concepts (gradient descent, logistic regression) and software libraries like pandas, tensorflow, etc\xa0',
#    'posted by': []},
#   {'title': 'Software Quality Assurance - Jogja',
#    'location': 'Jakarta, Indonesia',
#    'description': '\xa0Understand task requirements,\xa0create\xa0blackbox test case documentation, run test case thoroughly.Communicate with PM & Developers to ensure highly performing test phase in SDLCPrevent any bug appearances on production by found them all in test phaseOccasionally review software to found bug and flawsReport and investigate bugsProactively learn and help improve processes\xa0',
#    'qualification': "Minimum Requirement:Have experience in manual testing web or mobile appsFamiliarity with Javascript, HTML and tools like Postman to check and validate test results.Enjoy doing thorough bug-seeking and case documentationSmart working, creative, detail-oriented, and strong analytical\xa0skills.Good verbal and written communication skills.Preferred Qualification:Bachelor's degree in\xa0Computer related major is a plus but not requiredUnderstand whitebox testing and has prior experience creating it is a big plus but not requiredCan create automated testing using Selenium or other methods is a big plus but not requiredHave programming experience is a plus but not required",
#    'posted by': 'Aldo Winata'},
#   {'title': 'Software Engineer - India',
#    'location': 'Bengaluru, Karnataka, India',
#    'description': "\xa0Contribute to all aspects of the software development lifecycle including design, development, documentation, testing and operationsCreate code that's easy to readWork with your team to maintain, improve and clean your codeReview each other's code and learn the software engineering best practices hereDeliver good quality code in a reasonable timeline\xa0",
#    'qualification': "Basic Qualifications:Bachelor’s Degree (S1) in Computer Science or related field. Or if you don't have a Bachelor's degree, prove to us that you can code at the same level as other software engineerProficiency in, at least, one programming language such as Java, Javascript, Python, Ruby, Rust, Go, HaskellHigh level understanding on how the internet works (HTTP, DNS, IP, Server-client interaction, etc)Preferred Qualifications (Not required but nice to have):Experience building scalable web servicesExperience in coding competitionsExperience with AWS or other PAAS.Experience with LinuxExperience with basic tooling like git, browser debugging, bash scripting, etc.Experience with Search & Personalization or Machine Learning",
#    'posted by': 'Aldo Winata'},
#   {'title': 'Android Developer (Freshgraduate,Senior,Principal, & Senior Principal Position)',
#    'location': 'Jakarta, Indonesia',
#    'description': "Develop the Android application for CermatiContribute to all aspects of the Android development lifecycle including design, development, documentation, testing and operationsCreate clean, easy to read code within reasonable timelineReview each other's code and learn the software engineering best practicesThis is a full time job and not an internship",
#    'qualification': "\xa0Bachelor's Degree (S1) in Computer Science or related field. Or if you don't have a Bachelor's degree, prove to us that you can code at the same level as other software engineerProficiency in, at least, one programming language such as Java, Javascript, Python, Ruby, Rust, Go, HaskellExperience in Android Native.Experience in Android development is a must. Having developed an Android app from scratch to publication is a big plus\xa0",
#    'posted by': 'Aldo Winata'},
#   {'title': 'VOIP / IT Call Center Manager',
#    'location': 'Jakarta, Indonesia',
#    'description': '\xa0Manage a team of IT staff to make sure requests on helpdesk are taken care within SLA and the tickets are resolved by the IT TeamCreate and help socialize IT SOP and IT GovernanceImprove IT to follow international recognized standardHelp in sourcing, recruiting and training IT Staff membersHas working technical knowledge of VoIP/IP telephony systems, \xa0IP-PBXs, software, and hardware, including Asteriks and/or Elastix platforms.Strong hands-on knowledge of the configuration and optimization of VoIP equipment, including switches, gateways, servers, telephones and other related equipment.Strong hands-on knowledge of protocols associated with VoIP.Strong understanding VoIP QoS issues and mitigation strategies.Strong understanding of the fundamentals in network communications in relation to VoIP.Working technical knowledge of Windows operating system.Direct experience with switches and routers.Expert in networking technologies.Knowledge of cabling and wiring systems, design, and installation.Ability to operate tools, components, peripherals, and testing accessories.\xa0',
#    'qualification': '\xa04+ years experience in managing large scale call center and it infrastructureHave experience managing at least 3 people for 1 yearS1 / D3 in telecommunications, computer science, or related field, and/or 3 years of direct work experience.Any IT Certifications a plus.\xa0',
#    'posted by': 'Oby Sumampouw'},
#   {'title': 'IOS Developer (Senior, Principal, & Senior Principal Position)',
#    'location': 'Central Jakarta, Central Jakarta City, Jakarta, Indonesia',
#    'description': "\xa0Develop the iOS application for Cermati\xa0Contribute to all aspects of the IOS development lifecycle including design, development, documentation, testing and operations\xa0Create clean, easy to read code within reasonable timeline\xa0Review each other's code and learn the software engineering best practices\xa0This is a full time job and not an internship\xa0",
#    'qualification': "\xa0Bachelor's Degree (S1) in Computer Science or related field. Or if you don't have a Bachelor's degree, prove to us that you can code at the same level as other software engineer\xa0Proficiency in, at least, one programming language such as Objective C, Swift, Java, Python, Javascript\xa0Experience in native iPhone and iPad development is a must.\xa0Having developed an IOS app from scratch to publication is a big plus\xa0",
#    'posted by': 'Aldo Winata'},
#   {'title': 'Software Quality Assurance',
#    'location': 'Jakarta, Indonesia',
#    'description': 'Create detailed, comprehensive and well-structured test plans and test cases.Perform all types of testing to ensure overall quality of the Product like user interface testing, functionality testing, performance testing, regression testing, integration testing, etc.Create & manage bug reports and communicate with the teamCollaborate with Engineering, UI/UX, Infrastructure and Product Management teams.Be an active part of analysis, design and planning activities.Be an enthusiastic advocate for good Agile practices.Eager to learn and grow as a professional.\xa0',
#    'qualification': "\xa0Bachelor's degree in Computer Science or Information Systems or other similar fieldsMinimum 1 year experience in Quality Assurance (Manual or automation)Experience in working with Web as well as Mobile applications (iOS & Android)Experience in API testing using tools like Postman, Jmeter, SoapUI, etc.Experience related to HTTP debugging on web and mobile based application (iOS & Android) using Developer tools/console.High level of comfort in using SQL for in-depth data testing.Experience in using test case and bug management tools like Phabricator, Test Rail, etc.Experience in working in Agile process methodology.Good interpersonal and communication skills. Should be comfortable with written and spoken English.Good analytical and problem-solving skills.Able to work independently or with limited assistance.Experience in programming languages like NodeJS, Java, Python, Ruby, etc is a plus but not required.Experience in Automation Testing using frameworks like Appium, Selenium, TestNG, Cucumber, TestCafe, NightwatchJS, etc. is a plus but not required.Experience in CI/CD process using Jenkins, Gitlab, etc. is a plus but not required.",
#    'posted by': 'Aldo Winata'},
#   {'title': 'Software Engineering Management (Lead, Manager, Head, VP level)',
#    'location': 'Jakarta, Indonesia',
#    'description': "Lead and mentor junior engineers to develop their skills and grow their careers at CermatiUnderstand Cermati's business and improve cermati's business with the help of your engineering teamHire and help the company find new engineering talentResponsible for managing, growing your team as well as your team member's promotions, demotions, hiring, firing, etc.Ensure that your team is happy, motivated and productive at CermatiWork with your team to build features, to maintain old code, improve and clean the code that your team ownsContribute to design decision and review each other's codeMake sure the code that your team owns will be available 24/7 and you're willing to troubleshoot and maintain the services that your team ownsWork together with product manager to set the feature specs and set the target deadline.Drive the projects so you can meet the deadline with your team",
#    'qualification': "Basic Qualifications:Bachelor’s Degree (S1) in Computer Science or related field. Or if you don't have a Bachelor's degree, prove to us that you can code at the same level as other software engineerProficiency in, at least, one programming language such as Java, Javascript, Python, Ruby, Rust, Go, HaskellHas high level understanding on how the internet works (HTTP, DNS, IP, Server-client interaction, etc)Experience building scalable web servicesProven record of good mentorship and leadership in delivering high quality projectsAt least 2 years experience working in a good tech oriented company (or if you don't have it, you can prove to us that you can gain the respect from a team of smart engineers and you can lead them to greatness)\xa0Preferred Qualifications (Not required but nice to have):Experience in coding competitionsExperience with AWS or other PAAS.Experience with LinuxExperience with basic tooling like git, browser debugging, bash scripting, etc.Experience with Search & Personalization or Machine Learning",
#    'posted by': 'Yovita Laurenzia'},
#   {'title': 'Software Engineer In Test (Senior, Principal, & Senior Principal Position)',
#    'location': 'West Jakarta, Kebon Jeruk, West Jakarta City, Jakarta, Indonesia',
#    'description': "Contribute to all aspects of the software development lifecycle including design, development, documentation, testing and operationsCreate code that's easy to readCreate automated testing that is fast, scalable, easily monitored and maintainedMake sure to increase the test coverage of our code using library like istanbul.jsWork with your team to maintain, improve and clean your codeReview each other's code and learn the software engineering best practices hereDesign a system to improve the quality of our code and automate the mundane stuff like auto-rollback if test is failing. Or Auto push code to production.\xa0This is a full time job and not an internship position",
#    'qualification': "Basic Qualifications:Bachelor’s Degree (S1) in Computer Science or related field. Or if you don't have a Bachelor's degree, prove to us that you can code at the same level as other software engineerProficiency in, at least, one programming language such as Java, Javascript, Python, Ruby, Rust, Go, HaskellHigh level understanding on how the internet works (HTTP, DNS, IP, Server-client interaction, etc)\xa0Preferred Qualifications (Not required but nice to have):Experience building scalable web servicesExperience in coding competitionsExperience with AWS or other PAAS.Experience with LinuxExperience with basic tooling like git, browser debugging, bash scripting, etc.Experience with Selenium, Nightwatch, CasperJS",
#    'posted by': 'Yovita Laurenzia'},
#   {'title': 'Frontend Developer (Freshgraduate, Senior, Principal, & Senior Principal Position)',
#    'location': 'Central Jakarta, Central Jakarta City, Jakarta, Indonesia',
#    'description': "\xa0Contribute to all aspects of the software development lifecycle including design, development, documentation, testing and operationsCreate code that's easy to readWork with your team to maintain, improve and clean your codeReview each other's code and learn software engineering best practice hereDeliver good quality code in a reasonable timelineThis is a full time job and not an internship position\xa0",
#    'qualification': "Basic Qualifications:Bachelor (S1) Degree in Computer Science or if you don't have a Bachelor's degree, prove to us that you can code at the same level as other software engineer (we have people in our team who doesn't have Bachelor in computer science)Experience and passion in web technologies styling, web performance and javascript (HTML5/CSS3/Javascript)Passion and curiosity to explore new things and keep abreast with new front end technologiesHas high level understanding on how the internet works (HTTP, DNS, IP, Server-client interaction, etc)\xa0Preferred Qualifications (Not required but nice to have):Proficiency in, at least, one programming language such as Java, PHP, Javascript, Python, Ruby, Rust, Go, Haskell.Comfortable working in server code although not very deepHas prior experience as a software developer or UX designerExperience with LinuxExperience with basic tooling like git, browser debugging, bash scripting, etc.Experience in coding competitionsUnderstand how to create a code with browser compatibility in different platform (android, desktop, iOS)",
#    'posted by': 'Aldo Winata'},
#   {'title': 'Front-End Engineer - Jogja',
#    'location': 'Yogyakarta, Jogja, Indonesia',
#    'description': 'Job Description:\xa0Contribute to all aspects of the software development lifecycle including design, development, documentation, testing and operations\xa0Write clean and testable code, as well as optimal code\xa0Work with your team to maintain and improve software quality\xa0Doing code review as part of the development lifecycle according to coding standards and current known best practices\xa0Deliver good quality code in a reasonable timeline',
#    'qualification': 'Minimum Qualifications: S1 degree with good algorithm & problem solving skills\xa0Excellent knowledge of web technologies such as HTML, CSS, and JavaScriptExperience with one of the following libraries / tools: React, Angular, VueHigh level understanding on the networking and security fundamentals\xa0Prefered Qualifications:Minimum of 2+ years of experience in software development and / or participating in coding competitions\xa0Good understanding on how to write performant & optimal front-end codesComfortable with UNIX / Linux environment',
#    'posted by': 'Aldo Winata'},
#   {'title': 'Software Engineer - Jogja',
#    'location': 'Yogyakarta, Jogja, Indonesia',
#    'description': 'Job Description:\xa0Contribute to all aspects of the software development lifecycle including design, development, documentation, testing and operationsWrite clean and testable code, as well as optimal codeWork with your team to maintain and improve software qualityDoing code review as part of the development lifecycle according to coding standards and current known best practicesDeliver good quality code in a reasonable timeline\xa0Write tests with at least 90% of test coverage',
#    'qualification': 'Minimum Qualifications:\xa0S1 degree with good algorithm & problem solving skills.Knowledge on how to build scalable system as well as maintainable system\xa0Excellent understanding with at least one of the following languages: NodeJS, Golang, Java, Python\xa0High level understanding on the networking and security fundamentalsPrefered Qualifications:\xa0Minimum of 2+ years of experience in software development and / or participating in coding competitions\xa0Good understanding on how to build efficient distributed systems\xa0Excellent understanding in NodeJS, MongoDB, PostgreSQL and know how to optimise javascript code as well as SQL query.\xa0Comfortable with UNIX / Linux environment\xa0Experience in managing infrastructure and services in GCP',
#    'posted by': 'Aldo Winata'},
#   {'title': 'Software Engineer (Freshgraduate, Senior, Principal, Architect Position)',
#    'location': 'West Jakarta, Kebon Jeruk, West Jakarta City, Jakarta, Indonesia',
#    'description': "Contribute to all aspects of the software development lifecycle including design, development, documentation, testing and operationsCreate code that's easy to readWork with your team to maintain, improve and clean your codeReview each other's code and learn the software engineering best practices hereDeliver good quality code in a reasonable timelineThis is a full time job and not an internship position",
#    'qualification': "Basic Qualifications:\xa0Bachelor’s Degree (S1) in Computer Science or related field. Or if you don't have a Bachelor's degree, prove to us that you can code at the same level as other software engineerProficiency in, at least, one programming language such as Java, Javascript, Python, Ruby, Rust, Go, HaskellHigh level understanding on how the internet works (HTTP, DNS, IP, Server-client interaction, etc)\xa0Preferred Qualifications (Not required but nice to have):Experience building scalable web servicesExperience in coding competitionsExperience with AWS or other PAAS.Experience with LinuxExperience with basic tooling like git, browser debugging, bash scripting, etc.Experience with Search & Personalization or Machine Learning",
#    'posted by': 'Aldo Winata'},
#   {'title': 'Business Intelligence Analyst',
#    'location': 'Jakarta, Indonesia',
#    'description': 'Provide support for the development of business intelligence solutions.Critically analyze internal data, provide insights and present findings to internal users.Work on complex cross-functional IT and business intelligence solutions.Provide timely reporting and work with business analysts to extract and present insights on operational performance to top management.Manage the reporting and analytics platform(s) to ensure that scheduled jobs are successfully run and analytics data aligns to timeliness / completeness requirementsBe part of a highly entrepreneurial and international team and take part in the creating of a leading internet venture with a focus on advancing financial technology.Managing the reporting and marketing analytics platform(s) to ensure web analytics data aligns to timeliness / completeness requirements.Working with the tech team to ensure that databases feeding the reporting platforms optimize',
#    'qualification': "\xa0Bachelor's Degree (S1) in Information System, Computer Science, Math, Statistics or related field.Good command of SQL, have the ability to write advanced DB queries in preferred languages (SQL as the minimum requirement, able to use Python/Java/Javascript is a plus).Ability to quickly disseminate data to find key trends, as well as ability to dive deep and mine the data behind these.Comfortable working with datasets containing millions of rows and creating complex visualizations from raw data in a live dashboard environment.Experience working as part of a data analytics team in an analytical and development capacity preferred is a plus.Excellent written and verbal communication skills.Experience working with analytical tools (R, Hadoop) is a plus2-3 years experience in MIS or similar role is preferable. Fresh graduates from reputable university are welcome.Ability to work well and deliver under pressure.",
#    'posted by': 'Regina Olivia'},
#   {'title': 'Product Manager / Product Owner (Entry, Mid and Senior Levels Available)',
#    'location': 'Jakarta, Indonesia',
#    'description': "\xa0Research, analyze, define product features and you create metrics to measure the impact of your product to the companyBe the primary driver of your product's planning and executionWrite the specs of new features and enhancementsCome up with product road map and rally other people to join your cause to realize your product vision. You are expected to be able to prototype your vision to convince others if necessary.Work with engineers, designers, ops, sales, legal and even external partners to make things happen\xa0",
#    'qualification': 'Basic Qualifications:Minimum Bachelor’s Degree (S1)Passionate in data-driven product development and has excellent analytical skills to process the dataDetail orientedStrong planner and very organizedA strong drive to make things happenSolid oral and written communications skillsPreferred Qualifications (Not required but nice to have):Has prior experience as a product manager / software developer / UX designer / project managerProficiency in, at least, one programming language such as Java, PHP, Javascript, Python, Ruby, Rust, Go, HaskellHas prior experience in agile product developmentHas advanced degrees i.e. Masters, Phd, MBA, etc',
#    'posted by': 'Regina Olivia'},
#   {'title': 'Senior UI/UX Designer',
#    'location': 'Central Jakarta, Central Jakarta City, Jakarta, Indonesia',
#    'description': 'Plan, think and design how user interact with our product (Start from wireframing into high fidelity mockup design)\xa0Design elements & assets based on thorough understanding of the users\xa0Create design accross multiples devices standard (Desktop, Android, iOS)',
#    'qualification': '\xa0Familiar using Sketch (Mac), Adobe Creative Suite (Ai, Ps, Xd), Zeplin, prototyping tools (Marvel/Invision)\xa0Bachelor (S1) in computer science (Human Computer Interaction), graphic design or related fields.\xa0Pixel perfect\xa0Good critical thinking\xa0Have a good design taste and keep up with newest design trends\xa0Have UI/UX portfolio\xa0Solid oral and written communication\xa0Preferred Qualifications:\xa0Has experience in setting up usability testing and analyzing data\xa0Has experience in creating mockup in HTML / CSS',
#    'posted by': 'Aldo Winata'},
#   {'title': 'Business Development Manager - Insurance',
#    'location': 'West Jakarta, Kebon Jeruk, West Jakarta City, Jakarta, Indonesia',
#    'description': "\xa0In charge of creating partnerships with E-Commerce, Travel, Hospitality, Gadget Supplier\xa0Companies that can benefit CermatiHave a deep understanding of both our product and the partners' product in order to create a successful partnershipPrepare an interesting and accurate customized presentation to be presented to potential partnersKeep a great ongoing relationships with current partners and offer new ways to grow the partnershipIdentify potential opportunities, create innovative strategies, and implement themResearching ways to increase the value of our products for our clients be it missing features, improvements, client feedback, etcCollaborate with the product team to create an effective strategy",
#    'qualification': [],
#    'posted by': []},
#   {'title': 'Partner Success Manager',
#    'location': 'Jakarta, Indonesia',
#    'description': '· Develop and manage existing merchants· Responsible for merchant growth. Drive usage and adoption of our product, using data and best practices.· Create and execute marketing campaign for merchant· Collaborate with Marketing Team to give more exposures on merchants· Generate performance report regularly and share insights to merchants for performance improvement',
#    'qualification': [],
#    'posted by': []},
#   {'title': 'Business Development Manager',
#    'location': 'Jakarta, Indonesia',
#    'description': "In charge of creating partnerships with e-commerce companies that can benefit CermatiHave a deep understanding of both our product and the partners' product in order to create a successful partnershipPrepare an interesting and accurate customized presentation to be presented to potential partnersKeep a great ongoing relationships with current partners and offer new ways to grow the partnershipIdentify potential opportunities, create innovative strategies, and implement themResearching ways to increase the value of our products for our clients be it missing features, improvements, client feedback, etcCollaborate with the product team to create an effective strategy",
#    'qualification': 'An independent and result-driven individual with the passion for networking and is able to maintain a good relationship with partners especially with e-commerce CompanyA smart individual, with superb interpersonal and communication skillSomeone who is able to work with little guidance yet produce creative initiativesVast network in e-commerce is preferredIndividuals with at least 2 (two) years of relevant work experience is preferred',
#    'posted by': []},
#   {'title': 'Relationship Manager - Funding',
#    'location': 'Jakarta, Indonesia',
#    'description': 'Grow portfolio of funding customers, and maintain the relationship with assigned clients.Attract new investment customers and educate new investors about investment opportunitiesManage day-to-day projects in a timely manner, ensuring that deliverable are met within the accuracyProactively implement strategies to monitor and enhance existing and new relationshipsTarget oriented and can work in a team to achieve team target\xa0Coordinate with other departments and various levels of management regarding transaction issues, credit risk reporting issues, including investigating data issues, and resolving reporting errors',
#    'qualification': '2 years experience in Bank / Insurances / Investments / Financial Services, exposure to managing investment fund on Time Deposit / Mutual Fund and Investment account\xa0Minimum Bachelor Degree, Tier 1 UniversityOutstanding analytical skills, strong and effective communication skills, Interpersonal skills/networking, as well as results orientedSpecific knowledge of the industry, including market, competitors and the main opportunities of the sectorDeep knowledge of financial products such as time deposit, mutual fund, Unit Link / ULIP and stockAble to create and sustain good personal contacts with clients, within the team and among the bank',
#    'posted by': 'Regina Olivia'},
#   {'title': 'Head of Insurance Product Marketplace',
#    'location': 'Jakarta, Indonesia',
#    'description': "Oversee the business development and operation team related to insurance products both general and life insurance such as auto insurance, health insurance, travel insuranceProspecting and sourcing new important general and life insurance clients and partnerships for Cermati.comEnsuring that new relationships are on-boarded smoothly to the platformManage and deepen existing relationships to improve product offerings and improve integration.Analyse client's performance on Cermati.com platform and having regular interactions with the PIC from client sideIncrease revenue per client by keeping a keen eye on profitability\xa0",
#    'qualification': 'Experienced in sales, business development and operations professionals in insurance industry or having consulting background for FIs for 5 years or moreHave experience in interacting with VP and Director level business leaders and managing strategic client relationship for the organisationHas large network in the insurance, insurance brokerage and corporate businessPrevious experience in an established insurance brokerage is a plusStrong communication, negotiation and analytical skillsAAAIK / AAIK Certification is major a plus.\xa0\xa0',
#    'posted by': []},
#   {'title': 'Head of Financial Product Marketplace - Bank and Multifinance',
#    'location': 'Jakarta, Indonesia',
#    'description': "Oversee the business development and operation team related to banking products\xa0Prospecting and sourcing new important clients and partnerships for Cermati.com from the banking and multi finance industryEnsuring that new relationships are on-boarded smoothly to the platformManage and deepen existing relationships to improve product offerings and improve integrationAnalyse client's performance on Cermati.com platform and having regular interactions with the PIC from client sideIncrease revenue per client by keeping a keen eye on profitability\xa0",
#    'qualification': 'Experienced in sales, business development and operations professionals in banking industry or having consulting background for FIs for 5 years or moreHave experience in interacting with VP and Director level business leaders and managing strategic client relationship for the organisationPrevious account management experience is a plusStrong communication, negotiation and analytical skills\xa0',
#    'posted by': 'Yovita Laurenzia'},
#   {'title': 'Insurance Technical Manager',
#    'location': 'West Jakarta, Kebon Jeruk, West Jakarta City, Jakarta, Indonesia',
#    'description': "Design customized insurance products according to client requirements & communicate it to the insurance partner, product manager, finance, and another stakeholders.\xa0Work together with business development to meet and analyse partner's needsAccompany business development when meeting with a prospect client and help to find out how insurance can be the client's marketing strategy / added value.\xa0Provide daily and weekly reporting to Chief Business Officer",
#    'qualification': 'Minimum 3 years of experience in insurance industryExperienced in general insurance industry, especially business/productExperienced in\xa0developing general insurance product\xa0Excellent written and verbal communication skillsUnderstand all aspects of a successful general insurance product throughout its life cycleGreat understanding of trend, recent news, ins and outs about insurance and fintech is a plusAble to work independently or in a team',
#    'posted by': 'Yovita Laurenzia'},
#   {'title': 'Insurance Employee Benefit Account Manager',
#    'location': 'Jakarta, Indonesia',
#    'description': 'Providing existing business and generate new business opportunities by actively contacting prospects, scheduling appointments, making sales presentations and closing new EB business accounts.Develop prospecting strategies to increase opportunities for new business.Build and maintain client relationships and provide oversight to account activity.Working closely with insurance partner for handling client claim settlement',
#    'qualification': 'Male/Female Max 35 Years OldMust have minimum 2 – 3 years as Employee Benefit Account Manager experience or equivalent in Insurance Company or Brokers. Additional insurance education or designation preferredMust have experience for maintaining employee benefit on large companyMust Have deep knowledge of Employee Benefit productMust be proficient in Ms Office and preparing presentationMust be highly organised and work well in team environment. Must have excellent interpersonal relationship skillsAbility to assess and maintain multiple priorities while managing one or more books of business',
#    'posted by': 'Yovita Laurenzia'},
#   {'title': 'Team Leader Desk Collection',
#    'location': 'West Jakarta, Jakarta, Indonesia',
#    'description': 'Coordinate collection activities of unsecured products, manage flow rates to prevent accounts from flowing down to charge off and minimize net credit lossesRecruitment, training and performance management of the collection team to ensure good productivityProcess-reengineering of collection processes to improve productivityCapacity tracking, management and planning to ensure adequate collection resources for the section all the timeManage and optimize collection costPrepare, document and monitor strategy effectiveness and custody of the collection strategy/procedureTracking and evaluating the effectiveness of all collection strategies. Design and conduct champion & challenger tests of all collection strategiesPrepares regular and customized, in-depth reports and information summarizing various aspects of unit(s) activities. Interprets important aspects of reports for management.',
#    'qualification': "Bachelor's degree\xa05 years of working experience in Collection and 1-2 years of working experience as Desk Collection Supervisor/ManagerStrong understanding of collections activities and process.\xa0Sound people supervisory/managerial skills.Excellent problem-solving skills.\xa0Advanced Communication skills, both verbal and written.Adequate analytical skills and has experience in developing collection reports to measure collection productivity/performance.Experience with collection strategy to achieve both short term and long term desirable result/portfolio quality.\xa0Ms-office skills.",
#    'posted by': 'Yovita Laurenzia'},
#   {'title': 'Field Collection',
#    'location': 'West Jakarta, Indonesia',
#    'description': '\xa0Mengunjungi debitur dan melakukan pengiriman Surat Peringatan (SP) dalam masa tunggakan > 20 hari untuk melakukan validasi kondisi, analisa dan penagihan pembayaran kewajiban debitor yang belum diselesaikan.Menegosiasikan opsi pembayaran yang sesuai kepada nasabahMemonitor janji bayar debitur sesuai dengan masa tunggakan dan menagih kembali sesuai janji bayar.Mencari keberadaan pelanggan apabila tidak dapat ditemui baik di rumah maupun kantorMemastikan semua data pelanggan benar termasuk nomor telepon dan alamatMelaporkan dan mendiskusikan dengan atasan mengenai hasil kunjungan/penanganan. Membuat catatan atas setiap aktivitas penagihan ke dalam collection system.Melakukan koordinasi dengan pihak internal collection maupun unit terkait sehubungan dengan penanganan debitor\xa0\xa0',
#    'qualification': '\xa0Minimal pengalaman 2 tahun di bank dan/atau multifinance (mempunyai pengalaman di industri fintech akan menjadi nilai tambah)Memiliki kendaraan bermotor dan minimal SIM CMinimal SMU atau sederajatMempunyai kemampuan komunikasi dan negosasi yang baikMempunyai kompetensi yang baik terutama di bidang field collection (penagihan lapangan) untuk pinjaman tanpa jaminanMemiliki persistensi dan orientasi yang kuat terhadap Pencapaian TargetMampu bekerja sama dalam team dengan interpersonal skill yang baikFamiliar dengan penggunaan Aplikasi Komputer dan Microsoft OfficeWalk-in interview :setiap hari Selasa, Jam : 13.00 - 15.00 WIB.Lokasi di Gedung Cermati.comJl. Tomang Raya No.38, RT.5/RW.1, Jatipulo, Palmerah, Kota Jakarta Barat, Daerah Khusus Ibukota Jakarta 11430',
#    'posted by': []},
#   {'title': 'Anti Fraud Analyst',
#    'location': 'West Jakarta, Kebon Jeruk, West Jakarta City, Jakarta, Indonesia',
#    'description': 'Job purposeAs part of Credit Risk Team to minimize risk, detect and prevent fraudDuties and responsibilitiesManage and responsible for the overall Anti-fraud & investigation ProcessLiaise with Superior (Head of Credit Ops)Responsible to maintain daily and weekly reportDevelops fraud model prevention initiativesRecovers fraud lossesCoordinate collaborations with other departments.Monitoring and developing team performance and coaching if needed',
#    'qualification': 'QualificationsMale/FemaleAge max. 35 years’ oldBachelor degree any majorMinimum experience 3 years as fraud analyst, internal audit, risk policy in bank/multifinance/fintech preferably have experience in personal loan, retail loan, credit cardHave experience in data handling and processingHave experience in data analysisHave analytical background (knowledge of basic analytical tools such as SQL, Python, R, SAS, SPSS)Have honest attitude, conscientious and responsible.',
#    'posted by': 'Yovita Laurenzia'},
#   {'title': 'Desk Collection',
#    'location': 'Jakarta, Indonesia',
#    'description': '• Collect payments from the customers via Phone Calls\xa0• Keep tracking of assigned account to identify outstanding debt\xa0• Negotiate pay-off deadlines or payment plan\xa0• Investigate and resolve discrepancies while also create trust relationship with debtors when possible to avoid future issues\xa0• Take the initiative to make collection strategies\xa0• Doing work based on company and collection regulations\xa0• Will be able to Achieve the KPI for personal performance and team\xa0• Make activity report and regulary report to Team Leader\xa0',
#    'qualification': "• Candidate must possess at least SMU, Diploma, Bachelor's Degree in any field.\xa0• Required language: Bahasa Indonesia,\xa0• At least 1 Year(s) of working experience in the related field is required for this position.\xa0• Required Skill(s): Communication, Computer, Negotiation, Customer Handling, Collections\xa0• Preferably Staff (non-management & non-supervisor) specialized in Finance - Corporate Finance/Investment/Merchant Banking or equivalent.\xa0• Experienced in Fintech Industry will be advantage\xa0• Familiar with Collection Strategies and Creative in Negotiating Repayment Terms and Method\xa0• Have Experienced in Recovery is Plus\xa0• Good Computer Skills is A Must\xa0• Familiar with Collection's Target and KPI Achievement in Team\xa0• Able to Work Together with Team or by Yourself\xa0• Willing to Work Shiffting and Under Pressure\xa0• Will be Able Join ASAP\xa0Walk-in interview :Day\xa0 \xa0: Tuesday & ThursdayTime\xa0 : 9.00 A.M. - 11.00 AM.Location at\xa0 Cermati.comJl. Tomang Raya No.38, RT.5/RW.1, Jatipulo, Palmerah, Kota Jakarta Barat, Daerah Khusus Ibukota Jakarta 11430",
#    'posted by': 'Yovita Laurenzia'},
#   {'title': 'Telemarketing',
#    'location': 'Jakarta Barat, DKI Jakarta, Indonesia',
#    'description': 'Menelepon dan verifikasi data ke customerMenawarkan produk-produk finansial via teleponMengisi formulir dengan menggunakan program komputer yang tersediaMemastikan aplikasi terisi dengan lengkapMemastikan customer yang mendaftar ditindaklanjuti dengan cepat dan tanggap',
# ...
#    'posted by': 'Yovita Laurenzia'},
#   {'title': 'Head of Operation',
#    'location': 'Jakarta, Indonesia',
#    'description': 'Manage overall operation on the call center and logisticsStrategically hire, train, and manage Operation teamsImplement and refine \xa0process and procedures to improve overall operations and meet SLA’sPartner with product team to determine how technology help to streamline day to day operation.Previous experience managing and optimizing call center and logistics is highly\xa0proffered.\xa0Analyze key operations metrics to determine KPI and SLA for operation team.\xa0\xa0',
#    'qualification': '\xa05+ years of Operation\xa0ExcellenceExperience hiring and developing a telesales and logistic team.Experience coordinating projects &\xa0campaigns\xa0across teams.\xa0Ability to multitask and execute in a fast-paced, team-oriented environmentStrong analytical skills. Proven ability to review detailed data and produce meaningful analysisStrong problem solving skills and ability to identify root causesWorking knowledge of medium-large operationsBonus Points: Experience in managing large scale operation teams either in e-commerce or call centerPreferable comes from consulting company\xa0',
#    'posted by': []},
#   {'title': 'CEO Office - Special Projects',
#    'location': 'Jakarta, Indonesia',
#    'description': 'Be the gatekeeper of the CEO’s office and continually monitor the flow of information going in and out to the CEO’s officeMake sure that strategic projects and policies are followed up and completed in a timely manner ensuring high quality deliveryOversees and follows-up with staff on the timely and quality execution of planned activities related to strategic projects and decisions taken by the CEOCarry out research and relevant studies on topics related to business, product expansion, company expansion, competitive analysis, policy and others as required and prepare reports on findingsReviews and comments on materials and documents related to the execution of high profile strategic projects and programs being presented to the CEO thus ensuring accuracy and qualityMaintain accurate and up to date company data, reporting and communicationsAssist CEO in communicating\xa0in writing as well as in person from the CEO’s office to both internal staff and external high level officials and business executivesBe the gatekeeper of company policies, procedures and methods of operation to ensure compliance across the company',
#    'qualification': 'Minimum of 3 years in corporate planning and project managementAbility to lead cross-functional teams around strategic initiatives.Degree in Engineering, Business or Finance; MBA or other Graduate degree preferred.Experience in Management Consulting preferred.Proven business writing skills & analysis skills.Strong PowerPoint and Excel skills.Demonstrated organizational and team work skills.Strong communication skills (verbal and written) with the aptitude to communicate effectively in both individual and group settings regardless of audience.Able to think creatively, identify, and build support for innovative/outside-the-box solutions.',
#    'posted by': []},
#   {'title': 'Retail Credit Risk Analytics & Modelling Manager',
#    'location': 'Jakarta, Indonesia',
#    'description': 'Build credit risk modelling, analytics and reporting for retail customer• Strategically hire, train, and manage risk teamsPartner with product team to determine how technology help to detect and reduce risk.Previous experience building unsecured lending credit risk modelling is highly proffered.Analyze key metrics to determine risk.Mentoring and supporting junior members of the team will be a key part of the role, in both technical data manipulation skills and documentation delivery.Maintain the credit model platform which is utilised by the team and expected to provide advice and guidance on ongoing efficiency gains and new credit modelling methodology.',
#    'qualification': 'Have an undergraduate degree in an analytical discipline (e.g. maths, statistics), however other disciplines will be consideredHave 3+ experience of working in credit / risk modelling for retail customers especially unsecured lending in bank or non bankHave significant experience of credit modelling using statistic tool such as R, Phyton SAS, SQL analytical tools or advanced MS Excel skillsHave strong verbal and written skills that ensure you can explain technical concepts to less technically focused colleagues and produce suitable documentationBe organised, approachable, confident in engaging with stakeholders at all levels and a keen attention to detailExperience of reporting in a Financial environment.Experience and/or understanding of: data validation and verification techniques, advanced data manipulation techniques, development and production lifecycles, error handling, and automated reporting generation.',
#    'posted by': 'Yovita Laurenzia'},
#   {'title': 'Telesales Supervisor',
#    'location': 'Jakarta, Indonesia',
#    'description': 'Manage day to day operation on the call center and logisticsHire, train, and monitor telesales agentsImplement procedures to improve overall operations and meet SLA’s and sales targetPrevious experience managing and optimizing call center \xa0Analyze key operations metrics to determine KPI and SLA for telesales agents',
#    'qualification': '3+ years of \xa0Telesales ExperienceExperience in monitoring telesales and logistic team.Ability to multitask and execute in a fast-paced, team-oriented and sales driven environmentWorking knowledge of managing telesales team using CRM & Telesales system\xa0',
#    'posted by': []},
#   {'title': 'Telesales Assistant Manager - Bank / Insurance',
#    'location': 'West Jakarta, Indonesia',
#    'description': 'Manage overall operation on the call center and logisticsStrategically hire, train, and manage Operation teamsImplement and refine \xa0process and procedures to improve overall operations and meet SLA’sPartner with product team to determine how technology help to streamline day to day operation.Previous experience managing and optimizing call center and logistics is highly\xa0proffered.\xa0Analyze key operations metrics to determine KPI and SLA for operation team.\xa0\xa0',
#    'qualification': '\xa05+ years of \xa0Telesales Experience in Bank or InsuranceExperience hiring and developing a telesales and logistic team.Experience coordinating projects &\xa0campaigns\xa0across teams.\xa0Ability to multitask and execute in a fast-paced, team-oriented environmentStrong analytical skills. Proven ability to review detailed data and produce meaningful analysisStrong problem solving skills and ability identify root causesWorking knowledge of medium-large operations in bank or insurance call center\xa0Bonus Points: Experience in managing large scale operation teams either in bank or insurance call center\xa0',
#    'posted by': []},
#   {'title': 'Field Collection-Surabaya',
#    'location': 'Surabaya, Surabaya City, East Java, Indonesia',
#    'description': '\xa0Mengunjungi debitur dan melakukan pengiriman Surat Peringatan (SP) dalam masa tunggakan > 20 hari untuk melakukan validasi kondisi, analisa dan penagihan pembayaran kewajiban debitor yang belum diselesaikan.Menegosiasikan opsi pembayaran yang sesuai kepada nasabahMemonitor janji bayar debitur sesuai dengan masa tunggakan dan menagih kembali sesuai janji bayar.Menganalisa hasil penanganan dan melakukan tindakan sesuai dengan ruang lingkup/wilayah kerjanya dan apabila diperlukan.Mencari keberadaan pelanggan apabila tidak dapat ditemui baik di rumah maupun kantorMemastikan semua data pelanggan benar termasuk nomor telepon dan alamatMelaporkan dan mendiskusikan dengan atasan mengenai hasil kunjungan/penanganan. Membuat catatan atas setiap aktivitas penagihan ke dalam collection system.Melakukan koordinasi dengan pihak internal collection maupun unit terkait sehubungan dengan penanganan debitor\xa0\xa0',
#    'qualification': '\xa0Minimal pengalaman 2 tahun di bank dan/atau multifinance (mempunyai pengalaman di industri fintech akan menjadi nilai tambah)Memiliki kendaraan bermotor dan minimal SIM CMinimal SMU atau sederajatMempunyai kemampuan komunikasi dan negosasi yang baikMempunyai kompetensi yang baik terutama di bidang field collection (penagihan lapangan) untuk pinjaman tanpa jaminanMemiliki persistensi dan orientasi yang kuat terhadap Pencapaian TargetMampu bekerja sama dalam team dengan interpersonal skill yang baikFamiliar dengan penggunaan Aplikasi Komputer dan Microsoft Office\xa0',
#    'posted by': []},
#   {'title': 'Operations Strategist',
#    'location': 'West Jakarta, Kebon Jeruk, West Jakarta City, Jakarta, Indonesia',
#    'description': '·\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Our operations team grow so fast, you will\xa0develop and set\xa0scalable processes·\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Improve our current process to be more efficient.·\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0You will develop metrics & SLA of our operations process and maintain it at the most efficient and effective level.·\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0You will analyze the data, find the problems, develop the improvement recommendation, and implement the improvement plan.·\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0You will work\xa0closely\xa0with online sales and operations team for business process improvement and implementation.',
#    'qualification': '\xa0·\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Having experience at least for 3 years in Operation Excellence or operations improvements·\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Experience coordinating projects & campaigns across teams.·\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Ability to multitask and execute in a fast-paced, team-oriented environment·\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Strong analytical skills. Proven ability to review detailed data and produce meaningful analysis·\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Strong problem-solving skills and ability to identify root causes·\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Working knowledge of medium-large operations·\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Bonus Points: Experience in managing large scale operation projects either in e-commerce or call center',
#    'posted by': []},
#   {'title': 'Head Risk Analytics & Modelling',
#    'location': 'Jakarta, Indonesia',
#    'description': 'Build credit risk modelling, analytics and reporting for retail customerStrategically hire, train, and manage risk teamsPartner with product team to determine how technology help to detect and reduce risk.Analyze key metrics to determine risk. \xa0Mentoring and supporting junior members of the team will be a key part of the role, in both technical data manipulation skills and documentation delivery.\xa0Maintain the credit model platform which is utilised by the team and expected to provide advice and guidance on ongoing efficiency gains and new credit modelling methodology.',
#    'qualification': 'Have an undergraduate degree in an analytical discipline (e.g. maths, statistics), however other disciplines will be considered\xa0Have 5+ experience of working in credit / risk modelling for retail customers especially unsecured lending in bank or non bank\xa0Have significant experience of credit modelling using statistic tool such as R, Phyton SAS, SQL analytical tools or advanced MS Excel skillsPrevious experience building unsecured lending credit risk modelling is highly prefered.\xa0Have strong verbal and written skills that ensure you can explain technical concepts to less technically focused colleagues and produce suitable documentationBe organised, approachable, confident in engaging with stakeholders at all levels and a keen attention to detailExperience of reporting in a Financial environment.\xa0Experience and/or understanding of data validation and verification techniques, advanced data manipulation techniques, development and production lifecycles, error handling, and automated reporting generation.',
#    'posted by': []},
#   {'title': 'HR Operations Officer',
#    'location': 'Jakarta, Indonesia',
#    'description': "\xa0Be responsible for employee database, including attendance and leave managementManage payroll variables, including but not limited to attendance, incentive scheme, overtime.Make sure that payroll is done on time and with no errorsBe responsible for employee benefits management, including BPJS Ketenagakerjaan, BPJS Kesehatan, and health insuranceBe prudent and discreet about Cermati's payroll and employee data\xa0",
#    'qualification': '\xa0Around 1\xa0year\xa0experience in a similar capacityProficient in MS Excel and its functions, including conditional formatting and other data analysis functionsAble to work fast and meticulously under pressureExperience in payroll system and its implementation is a plusPosses a motivation to grow and explore\xa0\xa0',
#    'posted by': []},
#   {'title': 'Learning & Development Specialist',
#    'location': 'Jakarta, Indonesia',
#    'description': 'Work closely with each department head in performing Training Need Analysis (TNA)Deliver various training modules as necessary\xa0Support people managers in providing the right coaching and people management to their team members\xa0Conduct research on a variety of talent development topics, trends, and best in class practicesCompile metrics and report on overall training program engagement & effectiveness\xa0Partner with learning platforms and organizations in understanding overall L&D Opportunities and relevance to company needs\xa0',
#    'qualification': 'Professional experience at least 2 years in related fields\xa0Bachelor degree in Human Resource Management, Public Relations, or any major related\xa0Self-driven, proactive and enthusiastic.Passionate in working with diverse group of people and in helping them to grow\xa0Ability to communicate clearly and properly in Bahasa Indonesia and EnglishProficient in designing and developing training module',
#    'posted by': 'Yovita Laurenzia'},
#   {'title': 'VP Of People Ops',
#    'location': 'Jakarta, Indonesia',
#    'description': 'Serve as a the leader for the People Operation / Human Resources teamAdvise, counsel and influence the business leadership team in executing the people operation\xa0Drive change through organization design and operationalization of organizational modelsAdvise on recruiting, performance management, employer branding and culture issuesLead the company key talent acquisition effortDrive initiatives focused on employee satisfactionLead the performance management process processLead initatives across the HR team',
#    'qualification': '\xa010+ years HR experience that includes HR generalist/business partner/Recruitment\xa0experience and managing HR teamConsulting, Technology and Finance industry experience strongly preferredExtensive experience in stakeholder management around complex strategic HR issues such as talent management, org design/development, change management, compensation and employee relationsProven track record in developing strategy and driving change to help drive business results and execute on key initiativesSuperb relationship management skills, project management\xa0and the ability to develop strong interpersonal alliances at all levelsDeep technical HR competence with the ability to influence using a balance of technical HR expertise, business acumen and relationship skillsBusiness driven individual with strong financial acumenHigh level of interpersonal skills and integrity; solid team playerAble to achieve results quickly in a fast-paced organization; thrives in a high intensity environment with multiple and competing prioritiesUnquestionable business and personal integrity and values congruent with those of the organization\xa0',
#    'posted by': []}]}

# %% [markdown]
# # Creating JSON

# %%
import copy
answer=copy.copy(json.loads(json.dumps(full_data)))
